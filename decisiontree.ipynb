# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
import matplotlib.pyplot as plt

# %%
data=load_iris()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)
df['target']=data.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df[data.feature_names],df['target'])

# %%
clf = DecisionTreeClassifier(max_depth = 2, 
                             random_state = 0)
clf
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
clf.predict(xtest)
# Out:
# array([1, 2, 2, 2, 2, 0, 2, 0, 0, 0, 1, 0, 2, 0, 0, 1, 0, 0, 1, 0, 1, 0,
#        0, 1, 2, 1, 1, 1, 2, 2, 1, 0, 1, 0, 2, 2, 2, 1])

# %%
from sklearn import tr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       2 cn=['setosa', 'versicolor', 'virginica']
#       3 fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
# ----> 4 tree.plot_tree(clf,
#       5                feature_names = fn,
#       6                class_names=cn,
#       7                filled = True);
#       8 fig.savefig('imagename.png')
#
# NameError: name 'tree' is not defined
