# %%
from sklearn.svm import SVC
import pandas as pd
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/MrKow/OneDrive/Desktop/jupyter programs/iris.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.isnull().sum()
x=data.iloc[:,:-1]
y=data[['species']]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
svc=SVC()
svc.fit(xtrain,ytrain)
accuracy_score(ytest,svc.predict(xtest))
# Out:
# C:\Users\MrKow\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
svc=SVC(C=0.1)
svc.fit(xtrain,ytrain)
accuracy_score(ytest,svc.predict(xtest))
# Out:
# C:\Users\MrKow\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9

# %%
svc=SVC(C=10)
svc.fit(xtrain,ytrain)
accuracy_score(ytest,svc.predict(xtest))
# Out:
# C:\Users\MrKow\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0

# %%
svc=SVC(gamma=0.1)
svc.fit(xtrain,ytrain)
accuracy_score(ytest,svc.predict(xtest))
# Out:
# C:\Users\MrKow\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667

# %%
import seaborn as sns
sns.pairplot(data,hue="species", palette="CMRmap")
